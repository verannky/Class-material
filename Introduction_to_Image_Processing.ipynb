# %% [markdown]
# # Setup

# %%
# !git clone https://github.com/tanvipenumudy/Winter-Internship-Internity.git
# Out:
# fatal: destination path 'Winter-Internship-Internity' already exists and is not an empty directory.

# %%
path = '/content/Winter-Internship-Internity/Day 05/images/'

# %% [markdown]
# # CV2
#
# cv2 is one of the computer vision library. CV can import image as a numpy array format.

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread(path+'logo.jpg')
img
# Out:
# array([[[  1,   3, 198],
#         [  2,   5, 197],
#         [  1,   1, 195],
#         ...,
#         [ 10,  29, 210],
#         [ 17,  35, 212],
#         [ 13,  31, 208]],
#
#        [[  2,   2, 202],
#         [  1,   1, 201],
#         [  1,   1, 203],
#         ...,
#         [  7,  28, 214],
#         [  9,  26, 213],
#         [ 13,  31, 214]],
#
#        [[  1,   0, 204],
#         [  0,   1, 205],
#         [  1,   0, 204],
#         ...,
#         [ 13,  25, 219],
#         [ 10,  29, 216],
#         [  7,  27, 216]],
#
#        ...,
#
#        [[  0,   0, 204],
#         [  0,   0, 206],
#         [  0,   0, 204],
#         ...,
#         [ 17,  33, 223],
#         [ 10,  35, 223],
#         [ 15,  34, 223]],
#
#        [[  0,   0, 204],
#         [  0,   0, 206],
#         [  0,   0, 204],
#         ...,
#         [ 14,  33, 222],
#         [ 15,  34, 223],
#         [ 14,  33, 222]],
#
#        [[  0,   0, 204],
#         [  0,   0, 204],
#         [  0,   0, 206],
#         ...,
#         [ 18,  35, 222],
#         [ 15,  34, 221],
#         [ 15,  34, 223]]], dtype=uint8)

# %%
img.shape
# Out:
# (260, 462, 3)

# %%
img = cv.imread(path + '/logo.jpg')
plt.imshow(img)

# %%
img_re = cv.resize(img,(300,300))
plt.imshow(img_re)

# %%
img_gray = cv.cvtColor(img,cv.COLOR_RGB2GRAY)
plt.imshow(img_gray,cmap='gray')

# %%
img_flat = img.flatten().shape

# %% [markdown]
# # Harr Like Feature
#
# Berusaha mendeteksi berdasarkan pattern tertentu

# %%
from skimage.feature import haar_like_feature
from skimage.transform import integral_image

# %%
img_re = cv.resize(img,(128,128))
plt.imshow(img_re)

# %%
img_gr = cv.cvtColor(img_re,cv.COLOR_RGB2GRAY)
plt.imshow(img_gr,cmap='gray')

# %%
# To speed up the example, extract the two types of features only
feature_types = ['type-2-x','type-2-y']

# %%
ii = integral_image(img_gr)

# %%
results=haar_like_feature(ii, 0, 0, ii.shape[0], ii.shape[1],
                             feature_type=feature_types)

# %%
results.shape
# Out:
# (104400,)

# %% [markdown]
# # LBP
# LBP (Local Binary Pattern) merupakan salah satu metode yang dapat mengextract data image agar siap dianalisis menjadi feature

# %%
img_messi = cv.imread(path+'messi.jpg')
plt.figure(figsize=(10,7))
plt.imshow(img_messi,cmap='gray')

# %%
img_messi = cv.cvtColor(img_messi, cv.COLOR_BGR2RGB)
plt.figure(figsize=(10,7))
plt.imshow(img_messi,cmap='gray')

# %%
img_messi = cv.cvtColor(img_messi, cv.COLOR_RGB2GRAY)
plt.figure(figsize=(10,7))
plt.imshow(img_messi,cmap='gray')

# %%
from skimage import feature

# %%
num_points=8
radius=1

img_lbp = feature.local_binary_pattern(img_messi,num_points,radius)

# %%
plt.figure(figsize=(10,7))
plt.imshow(img_lbp,cmap='gray')

# %%
num_points=24
radius=2

img_lbp = feature.local_binary_pattern(img_messi,num_points,radius)
plt.figure(figsize=(10,7))
plt.imshow(img_lbp,cmap='gray')

# %%
flat_lbp = img_lbp.flatten()
plt.hist(flat_lbp)
# Out:
# (array([33518., 18947., 16522.,  2889., 18313., 13349.,  2606., 16506.,
#         17532., 47234.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
hist, _ = np.histogram(flat_lbp,
                       bins=np.arange(0,2**num_points+1),
                       range=np.arange(0,2**num_points))

# %%
hist = hist/np.sum(hist)
hist
# Out:
# array([3.40998375e-02, 1.10501010e-02, 1.47805764e-03, 4.25789854e-03,
#        9.76422448e-03, 1.75017258e-03, 5.09558572e-03, 2.19720479e-02,
#        1.57409821e-03, 4.48289318e-04, 1.70838786e-04, 4.05604621e-04,
#        4.82880637e-03, 8.59129528e-04, 1.25494010e-02, 4.31863424e-02,
#        1.11354704e-02, 4.08182416e-03, 4.21611382e-04, 8.32451592e-04,
#        1.64879643e-03, 3.14899639e-04, 7.41746611e-04, 1.25396298e-03,
#        4.17252915e-03, 7.47082198e-04, 2.45537006e-04, 6.77719565e-04,
#        2.00565721e-02, 1.25396298e-03, 3.53056801e-02, 3.45373556e-02,
#        1.36067472e-03, 3.73591098e-04, 5.87914561e-05, 1.12147328e-04,
#        3.14899639e-04, 5.34558689e-05, 1.38825263e-04, 2.56208180e-04,
#        1.38825263e-04, 3.21135203e-05, 1.61067589e-05, 4.27846946e-05,
#        1.70838786e-04, 7.47982175e-05, 2.13523483e-04, 5.12316364e-04,
#        4.14051562e-03, 8.59129528e-04, 1.49496438e-04, 1.97516722e-04,
#        6.35034868e-04, 1.01476153e-04, 1.86845548e-04, 3.73591098e-04,
#        8.91053053e-03, 7.15068675e-04, 1.81509960e-04, 4.53624905e-04,
#        3.52736666e-02, 7.31075437e-04, 1.35151422e-02, 9.08126932e-03,
#        9.39606896e-03, 1.59544055e-03, 3.36241988e-04, 6.45706042e-04,
#        2.60386652e-03, 1.70838786e-04, 8.05773657e-04, 1.06721743e-03,
#        2.88221703e-04, 7.47982175e-05, 6.94626303e-05, 5.87914561e-05,
#        6.88390739e-04, 9.61405661e-05, 9.55170097e-04, 1.01386156e-03,
#        1.47805764e-03, 3.09564052e-04, 8.01338046e-05, 1.12147328e-04,
#        2.08187896e-04, 5.34558689e-05, 8.54693918e-05, 8.01338046e-05,
#        5.60336648e-04, 1.01476153e-04, 6.94626303e-05, 7.47982175e-05,
#        1.08855978e-03, 1.28154089e-04, 1.15792241e-03, 1.23795622e-03,
#        4.63672523e-03, 7.63088959e-04, 1.54832025e-04, 1.76174373e-04,
#        7.25739849e-04, 6.94626303e-05, 1.60167612e-04, 2.40201419e-04,
#        1.24907095e-02, 8.86251025e-03, 5.49665474e-04, 7.45391524e-03,
#        8.29693801e-03, 6.09867611e-03, 8.91053053e-03, 6.96935393e-02])

# %%
# import the necessary packages
def LocalBinaryPatterns(image,num_points,radius):
		# compute the Local Binary Pattern representation
		# of the image, and then use the LBP representation
		# to build the histogram of patterns
		lbp = feature.local_binary_pattern(image, num_points,radius)
		(hist, _) = np.histogram(lbp.ravel(),
			bins=np.arange(0, 2**num_points + 1),
			range=(0, 2**num_points))
	
		# normalize the histogram
		hist = hist.astype("float")
		hist /= (hist.sum())
		# return the histogram of Local Binary Patterns
		return hist

# %%
LocalBinaryPatterns(img_messi,8,1)
# Out:
# array([3.37644598e-02, 1.07034618e-02, 1.31258804e-03, 3.86839971e-03,
#        9.49225253e-03, 1.63273146e-03, 4.63140820e-03, 2.10761088e-02,
#        1.53135271e-03, 4.58872241e-04, 1.97421778e-04, 4.42865070e-04,
#        4.61540103e-03, 8.11030008e-04, 1.21921287e-02, 4.48307508e-02,
#        1.04420114e-02, 4.16186452e-03, 4.00179280e-04, 8.64387245e-04,
#        1.52068127e-03, 2.45443292e-04, 7.79015666e-04, 1.16852350e-03,
#        3.99112136e-03, 8.05694284e-04, 2.56114739e-04, 6.08272506e-04,
#        2.00943356e-02, 1.13117343e-03, 3.66137363e-02, 3.45221326e-02,
#        1.41396679e-03, 3.78836385e-04, 6.40286849e-05, 1.33393093e-04,
#        2.93464806e-04, 6.93644086e-05, 1.65407436e-04, 2.24100397e-04,
#        1.49400265e-04, 4.80215136e-05, 1.60071712e-05, 3.73500662e-05,
#        1.70743160e-04, 6.93644086e-05, 2.50779016e-04, 5.76258164e-04,
#        3.61762069e-03, 7.25658428e-04, 1.28057370e-04, 2.02757502e-04,
#        6.66965467e-04, 8.53715798e-05, 1.92086055e-04, 3.30814872e-04,
#        8.93200154e-03, 6.02936782e-04, 2.08093226e-04, 4.05515004e-04,
#        3.64376574e-02, 7.09651257e-04, 1.39315747e-02, 8.69722969e-03,
#        9.05472318e-03, 1.52601699e-03, 3.25479148e-04, 5.86929611e-04,
#        2.49711871e-03, 1.76078883e-04, 7.57672771e-04, 1.02979468e-03,
#        2.77457634e-04, 6.40286849e-05, 7.47001323e-05, 4.80215136e-05,
#        6.77636915e-04, 8.53715798e-05, 9.12408759e-04, 9.28415930e-04,
#        1.46198830e-03, 2.77457634e-04, 6.93644086e-05, 1.17385922e-04,
#        1.54735988e-04, 3.73500662e-05, 7.47001323e-05, 1.17385922e-04,
#        5.12229479e-04, 1.01378751e-04, 6.40286849e-05, 1.12050198e-04,
#        1.05647330e-03, 1.12050198e-04, 9.01737312e-04, 1.14184488e-03,
#        4.28992189e-03, 7.30994152e-04, 1.17385922e-04, 1.81414607e-04,
#        7.36329876e-04, 9.07073035e-05, 1.81414607e-04, 2.24100397e-04,
#        1.76078883e-04, 3.73500662e-05, 4.26857899e-05, 2.13428950e-05,
#        3.73500662e-04, 4.80215136e-05, 5.28236650e-04, 4.90886584e-04,
